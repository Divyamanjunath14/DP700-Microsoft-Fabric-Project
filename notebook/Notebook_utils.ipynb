# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
import notebookutils
# Out:
# StatementMeta(, 50a05e2d-2b11-4100-b1dc-d8aef8a08a8b, 3, Finished, Available, Finished, False)

# %% [markdown]
# ##### **fs ls**

# %%
for i in notebookutils.fs.ls("Files/"):
    print(i.path)
# Out:
# StatementMeta(, 50a05e2d-2b11-4100-b1dc-d8aef8a08a8b, 4, Finished, Available, Finished, False)
# abfss://29036564-f52b-4dfb-878c-bef487084c26@onelake.dfs.fabric.microsoft.com/bf43086d-6e88-4e1f-bb1d-2705db78bfba/Files/Source_Git
# abfss://29036564-f52b-4dfb-878c-bef487084c26@onelake.dfs.fabric.microsoft.com/bf43086d-6e88-4e1f-bb1d-2705db78bfba/Files/source_fabric
# abfss://29036564-f52b-4dfb-878c-bef487084c26@onelake.dfs.fabric.microsoft.com/bf43086d-6e88-4e1f-bb1d-2705db78bfba/Files/source_parquet_file

# %% [markdown]
# ##### cp

# %%
notebookutils.fs.cp("Files/Source_Git/olist_order_items_dataset.csv","Files/source_fabric")
# Out:
# StatementMeta(, 50a05e2d-2b11-4100-b1dc-d8aef8a08a8b, 5, Finished, Available, Finished, False)
# True

# %% [markdown]
# #### mv(move)

# %%
notebookutils.fs.mv("Files/Source_Git/olist_order_reviews_dataset.csv","Files/source_fabric")
# Out:
# StatementMeta(, 50a05e2d-2b11-4100-b1dc-d8aef8a08a8b, 7, Finished, Available, Finished, False)
# True

# %% [markdown]
# ##### rm(remove)

# %%
notebookutils.fs.rm("Files/source_fabric/olist_order_reviews_dataset.csv")
# Out:
# StatementMeta(, 50a05e2d-2b11-4100-b1dc-d8aef8a08a8b, 8, Finished, Available, Finished, False)
# True

# %% [markdown]
# ##### mkdirs(create directory)

# %%
notebookutils.fs.mkdirs("Files/new_folder_div")
# Out:
# StatementMeta(, 50a05e2d-2b11-4100-b1dc-d8aef8a08a8b, 10, Finished, Available, Finished, False)
# True

# %% [markdown]
# ##### put

# %%
notebookutils.fs.put("Files/new_folder_div/newfile.txt","I love divu")
# Out:
# StatementMeta(, 50a05e2d-2b11-4100-b1dc-d8aef8a08a8b, 11, Finished, Available, Finished, False)
# True
