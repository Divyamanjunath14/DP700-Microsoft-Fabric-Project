# %% [markdown]
# ### **Data Reading**

# %%
df_customers = spark.read.format("csv")\
                    .option("header", "true") \
                    .option("inferSchema", "true") \
                    .load("abfss://29036564-f52b-4dfb-878c-bef487084c26@onelake.dfs.fabric.microsoft.com/bf43086d-6e88-4e1f-bb1d-2705db78bfba/Files/Source_Git/olist_customers_dataset.csv")
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 32, Finished, Available, Finished, False)

# %%
df_orderitems = spark.read.format("csv")\
                    .option("header", "true") \
                    .option("inferSchema", "true") \
                    .load("abfss://29036564-f52b-4dfb-878c-bef487084c26@onelake.dfs.fabric.microsoft.com/bf43086d-6e88-4e1f-bb1d-2705db78bfba/Files/Source_Git/olist_order_items_dataset.csv")
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 33, Finished, Available, Finished, False)

# %%
display(df_orderitems)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 34, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 72cf055e-deed-4068-b2c2-9dcb4818e7ca)

# %%
display(df_customers.limit(5))
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 35, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 3ef423cf-0a79-4dac-afd2-5f212c9e7a10)

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 36, Finished, Available, Finished, False)

# %% [markdown]
# #### select

# %%
df_customers = df_customers.select("customer_unique_id","customer_id","customer_zip_code_prefix")
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 37, Finished, Available, Finished, False)

# %%
display(df_customers)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 38, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 623c6259-429a-43fd-9232-f2af3f6c70f7)

# %% [markdown]
# #### withColumnRenamed

# %%
df_customers = df_customers.withColumnRenamed("customer_unique_id","Unique_id")\
                           .withColumnRenamed("customer_zip_code_prefix","customer_zip_code")
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 39, Finished, Available, Finished, False)

# %%
display(df_customers)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 40, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, d8a7544a-5c27-463e-bb2e-a9c7c9d26742)

# %% [markdown]
# #### **TypeCasting**

# %%
df_customers = df_customers.withColumn("customer_zip_code",col("customer_zip_code").cast(IntegerType()))
display(df_customers)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 41, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 168eec7d-e505-41d0-9114-4fd299ad87d9)

# %%
df_payments = spark.read.option("inferSchema",True)\
               .format("csv").option("header","true").load("abfss://29036564-f52b-4dfb-878c-bef487084c26@onelake.dfs.fabric.microsoft.com/bf43086d-6e88-4e1f-bb1d-2705db78bfba/Files/Source_Git/olist_order_payments_dataset.csv")
display(df_payments)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 42, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 8faaeaf9-7f44-48cf-9608-c8775583674f)

# %% [markdown]
# ##### Replace Values

# %%
from pyspark.sql.functions import regexp_replace
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 43, Finished, Available, Finished, False)

# %%
df_payments = df_payments.withColumn("payment_type",regexp_replace(col("payment_type"),"_"," "))\
                        .withColumn("payment_installments",col("payment_installments").cast(IntegerType()))\
                        .withColumn("payment_value",col("payment_value").cast(IntegerType()))
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 44, Finished, Available, Finished, False)

# %%
display(df_payments)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 45, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 6d8b5320-0773-48de-a73d-7cfc557e649a)

# %%
df_reviews = spark.read.option("inferSchema",True)\
                      .format("csv").option("header","true").load("abfss://29036564-f52b-4dfb-878c-bef487084c26@onelake.dfs.fabric.microsoft.com/bf43086d-6e88-4e1f-bb1d-2705db78bfba/Files/Source_Git/olist_order_reviews_dataset.csv")
display(df_reviews)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 46, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 348cee41-38fe-4ea3-b1fd-5a9ad3cc5885)

# %%
from pyspark.sql.functions import upper, lower
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 47, Finished, Available, Finished, False)

# %%
df_reviews = df_reviews.withColumn("review_comment_title",upper("review_comment_title"))\
                       .withColumn("review_comment_message",lower("review_comment_message"))
display(df_reviews)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 48, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 6edc9b80-9f28-4afb-99e9-34c225754fc5)

# %%
df_category = spark.read.format("csv")\
               .option("header","true")\
               .option("inferSchema",True)\
               .load("abfss://29036564-f52b-4dfb-878c-bef487084c26@onelake.dfs.fabric.microsoft.com/bf43086d-6e88-4e1f-bb1d-2705db78bfba/Files/Source_Git/product_category_name_translation.csv")
display(df_category)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 49, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 2a878d81-516b-4c4b-8fb7-2bb738436f2e)

# %%
df_products = spark.read\
               .format("csv")\
               .option("inferSchema",True)\
               .option("header","true")\
               .load("abfss://29036564-f52b-4dfb-878c-bef487084c26@onelake.dfs.fabric.microsoft.com/bf43086d-6e88-4e1f-bb1d-2705db78bfba/Files/Source_Git/olist_products_dataset.csv")
display(df_products)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 50, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, d884c74a-1c03-4687-acf2-7d05c7b33657)

# %% [markdown]
# ##### **HandlingNulls**

# %%
df_products = df_products.withColumnRenamed("product_description_lenght","product_description_length")\
                         .withColumnRenamed("product_name_lenght","product_name_length")
display(df_products)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 51, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 156d2d6f-caf0-4167-9715-570b04d680c1)

# %%
df_products.printSchema
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 52, Finished, Available, Finished, False)
# <bound method DataFrame.printSchema of DataFrame[product_id: string, product_category_name: string, product_name_length: int, product_description_length: int, product_photos_qty: int, product_weight_g: int, product_length_cm: int, product_height_cm: int, product_width_cm: int]>

# %%
df_products = df_products.fillna({"product_category_name":"x","product_name_length":"0","product_photos_qty":"0"})
display(df_products)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 53, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 65ffadd7-3b5b-4577-a4a8-319b08924a2f)

# %%
#display(df_products = df_products.filter(col("product_weight_g")>300))
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 54, Finished, Available, Finished, False)

# %% [markdown]
# #### **Flagging create a new column**

# %%
df_products = df_products.withColumn("300gFlag",when(col("product_weight_g")>300,"Y").otherwise("N"))
display(df_products)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 55, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, e65ace68-be17-4387-9654-6acf03e027d5)

# %%
df_orders = spark.read\
                .format("csv")\
                .option("header","true")\
                .option("inferSchema",True)\
                .load("abfss://29036564-f52b-4dfb-878c-bef487084c26@onelake.dfs.fabric.microsoft.com/bf43086d-6e88-4e1f-bb1d-2705db78bfba/Files/Source_Git/olist_orders_dataset.csv")
display(df_orders)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 56, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 8fc26f70-0326-40dd-a037-eee38f69fa26)

# %%
df_orders = df_orders.dropna(subset = ["order_delivered_carrier_date","order_delivered_customer_date"])
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 57, Finished, Available, Finished, False)

# %%
display(df_orders)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 58, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, c50c5cae-138d-41fc-a2c4-c36a7aca243d)

# %%
df_orders.createOrReplaceGlobalTempView("order_temp_view")
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 59, Finished, Available, Finished, False)

# %%
#%%sql
# select * from order_temp_view
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 61, Finished, Available, Finished, False)

# %% [markdown]
# ##### **Visualization**

# %%
display(df_products)
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 62, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 62d2a18f-17fc-45af-93a8-25f04e6397ca)

# %% [markdown]
# #### **Writing file**

# %%
df_orders.write.format("delta")\
         .mode("append")\
         .option("path","Files/Source_Git")\
         .save()
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 63, Finished, Available, Finished, False)

# %% [markdown]
# ##### **writing as a managed table**

# %%
df_orders.write.format("delta")\
               .mode("append")\
               .saveAsTable("delta_man_tbl")
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 64, Finished, Available, Finished, False)

# %% [markdown]
# ##### **writing as external table**

# %%
df_customers.write.format("delta")\
                  .mode("append")\
                  .saveAsTable("Silver.enr_customers")

df_reviews.write.format("delta")\
                  .mode("append")\
                  .saveAsTable("Silver.enr_reviews")
        
df_payments.write.format("delta")\
                  .mode("append")\
                  .saveAsTable("Silver.enr_payments")

df_orderitems.write.format("delta")\
                  .mode("append")\
                  .saveAsTable("Silver.enr_orderitems")

df_products.write.format("delta")\
                  .mode("append")\
                  .saveAsTable("Silver.enr_products")

df_orders.write.format("delta")\
                  .mode("append")\
                  .saveAsTable("Silver.enr_orders")
# Out:
# StatementMeta(, aecec094-5665-444e-99ff-d0c08e85311d, 72, Finished, Available, Finished, False)
